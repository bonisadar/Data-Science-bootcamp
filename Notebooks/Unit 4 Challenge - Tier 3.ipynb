# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# import the pandas, numpy, seaborn libraries as pd, np and sns respectively. 
import pandas as pd
import numpy as np
import seaborn as sns

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# load ticker module from matplotlib as mtick
import matplotlib.ticker as mtick

# %%
# Suppress scientific notation
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head() # Showing the first five rows for observation
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01       91448.98           50460.23   93284.52   64958.09
# 2 1995-02-01       82202.77           51085.78   93190.17   64787.92
# 3 1995-03-01       79120.70           51268.97   92247.52   64367.49
# 4 1995-04-01       77101.21           53133.51   90762.87   64277.67
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1   71306.57   81671.48  120932.89   69158.16   79885.89  ...   43958.48
# 2   72022.26   81657.56  119508.86   68951.10   80897.07  ...   43925.42
# 3   72015.76   81449.31  120282.21   68712.44   81379.86  ...   44434.87
# 4   72965.63   81124.41  120097.90   68610.05   82188.90  ...   44267.78
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties = properties.transpose()

# %%
properties = properties.reset_index() # Setting the idex to integer values

# %%
properties.columns = properties.iloc[0] # Setting the first row as column lebels

# %%
properties = properties.drop(0) # Droping the first row to avoid duplicate values

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# Renaming the column 'Unnamed:0' to 'London_borough'
properties.columns = properties.columns.to_series().replace({'Unnamed: 0': 'London_borough'})

# %%
properties = properties.drop(properties.columns[1], axis=1) # Removing the column labeled "NaT"

# %%
properties = properties.drop(index=[1] + list(range(34, 49))) # Deleting unnecessary rows

# %%
properties.reset_index(drop=True, inplace=True) # Droping the old index and modifying the data

# %%
properties.head()
# Out:
# 0      London_borough 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0  Barking & Dagenham            50460.23            51085.78
# 1              Barnet            93284.52            93190.17
# 2              Bexley            64958.09            64787.92
# 3               Brent            71306.57            72022.26
# 4             Bromley            81671.48            81657.56
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0            51268.97            53133.51            53042.25
# 1            92247.52            90762.87            90258.00
# 2            64367.49            64277.67            63997.14
# 3            72015.76            72965.63            73704.05
# 4            81449.31            81124.41            81542.62
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 0            53700.35            52113.12            52232.20
# 1            90107.23            91441.25            92361.32
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
columns_to_convert = properties.columns.drop('London_borough') # Excluding 'borough_names from type conversion'

# %%
# Converting the columns_to_convert to float
properties[columns_to_convert] = properties[columns_to_convert].apply(lambda col: pd.to_numeric(col, errors='coerce')).astype(float)

# %%
# Melting the dataframe fixing on the London_borough column
properties = properties.melt(id_vars=['London_borough'], var_name='Month', value_name='Average_price')

# %%
properties.head()
# Out:
#        London_borough                Month  Average_price
# 0  Barking & Dagenham  1995-01-01 00:00:00       50460.23
# 1              Barnet  1995-01-01 00:00:00       93284.52
# 2              Bexley  1995-01-01 00:00:00       64958.09
# 3               Brent  1995-01-01 00:00:00       71306.57
# 4             Bromley  1995-01-01 00:00:00       81671.48

# %%
# Subsetting the 'Month' column by droping the other two.
col_to_date = properties.columns.drop(['London_borough', 'Average_price'])

# %%
# Converting the 'Month' column to datatime format
properties[col_to_date] = properties[col_to_date].apply(lambda col:pd.to_datetime(col))

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties.isnull().any()
# Out:
# London_borough    False
# Month             False
# Average_price     False
# dtype: bool

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
bernet = properties[properties['London_borough'] == 'Barnet']

# %%
sns.lineplot(x='Month', y='Average_price', data=bernet)
# Out:
# <Axes: xlabel='Month', ylabel='Average_price'>

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
properties['Year'] = properties['Month'].dt.year # Extracting the year from 'Month' and assigning the values to a new column 'Year'

# %%
properties = properties[['London_borough', 'Month', 'Year', 'Average_price']] # Rearranging the column labels

# %%
properties
# Out:
#            London_borough      Month  Year  Average_price
# 0      Barking & Dagenham 1995-01-01  1995       50460.23
# 1                  Barnet 1995-01-01  1995       93284.52
# 2                  Bexley 1995-01-01  1995       64958.09
# 3                   Brent 1995-01-01  1995       71306.57
# 4                 Bromley 1995-01-01  1995       81671.48
# ...                   ...        ...   ...            ...
# 11355              Sutton 2024-07-01  2024      423468.00
# 11356       Tower Hamlets 2024-07-01  2024      452572.00
# 11357      Waltham Forest 2024-07-01  2024      483613.00
# 11358          Wandsworth 2024-07-01  2024      631945.00
# 11359         Westminster 2024-07-01  2024      904355.00
#
# [11360 rows x 4 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# # Function to return the ratio of Avg. price of London boroughs for the year 1998 and 2018 as a DataFrame

# %%
def create_price_ratio(*borough_names):
    '''Function to return the ratio of Avg. price of London boroughs for the year 1998 and 2018 as a DataFrame'''
    
    boroughs = []
    ratios = []
    
    for borough_name in borough_names:
        avg_1998 = properties[(properties['London_borough'] == borough_name) & (properties['Year'] == 1998)]['Average_price'].mean()
        avg_2018 = properties[(properties['London_borough'] == borough_name) & (properties['Year'] == 2018)]['Average_price'].mean()
        ratio_avg = avg_1998 / avg_2018
        
        boroughs.append(borough_name)
        ratios.append(ratio_avg)
        
    return pd.DataFrame({'London_borough': boroughs, 'Price_ratio':ratios})

# %%
# Creating a df consisting the average price and borough name
all_ratios_df = create_price_ratio(*properties['London_borough'].unique())

# %% [markdown]
# # Bottom 10 boroughs with lowest 1998 to 2018 price ratio

# %%
all_ratios_df.sort_values('Price_ratio').head(10)
# Out:
#           London_borough  Price_ratio
# 10               Hackney         0.16
# 29        Waltham Forest         0.17
# 26             Southwark         0.18
# 21              Lewisham         0.18
# 31           Westminster         0.19
# 23                Newham         0.19
# 12              Haringey         0.19
# 18  Kensington & Chelsea         0.20
# 20               Lambeth         0.20
# 5                 Camden         0.20

# %% [markdown]
# # Function to calculate the percentage increase in property prices

# %%
def percentage_price_increase(*borough_names):
    '''Function to return the percentage increase in price'''
    
    boroughs = []
    percentage_increase = []
    
    for borough_name in borough_names:
        avg_1998 = properties[(properties['London_borough'] == borough_name) & (properties['Year'] == 1998)]['Average_price'].mean()
        avg_2018 = properties[(properties['London_borough'] == borough_name) & (properties['Year'] == 2018)]['Average_price'].mean()
        per_inc = ((avg_2018 - avg_1998) / avg_1998) * 100
        
        boroughs.append(borough_name)
        percentage_increase.append(per_inc)
        
    return pd.DataFrame({'London_borough': boroughs, 'Price_increase(%)':percentage_increase})

# %%
# Creating a df consisting the average price and borough name
percentage_increase_df = percentage_price_increase(*properties['London_borough'].unique())

# %%
sorted_percentage_increase_df = percentage_increase_df.sort_values('Price_increase(%)', ascending=False)

# %% [markdown]
# # Top 10 borough with highest percentage price increase

# %%
sorted_percentage_increase_df.head(10)
# Out:
#           London_borough  Price_increase(%)
# 10               Hackney             519.83
# 29        Waltham Forest             483.51
# 26             Southwark             451.64
# 21              Lewisham             444.79
# 31           Westminster             435.27
# 23                Newham             430.77
# 12              Haringey             413.46
# 18  Kensington & Chelsea             408.22
# 20               Lambeth             395.82
# 5                 Camden             393.40

# %% [markdown]
# # Function to return the average price of boroughs in 2018 as a DataFrame

# %%
def create_price_2018(*borough_names):
    '''Function to return the average price of boroughs in 2018 as a DataFrame'''
    
    boroughs = []
    prices = []
    for borough_name in borough_names:
        avg_2018 = properties[(properties['London_borough'] == borough_name) & (properties['Year'] == 2018)]['Average_price'].mean()
        
        boroughs.append(borough_name)
        prices.append(avg_2018)
        
    return pd.DataFrame({'London_borough': boroughs, 'Prices_2018': prices})

# %%
# Creating a df consisting the average price and borough name
price_2018_df = create_price_2018(*properties['London_borough'].unique())

# %% [markdown]
# # Top 10 most expensive boroughs in 2018

# %%
price_2018_df.sort_values('Prices_2018', ascending=False).head(10)
# Out:
#           London_borough  Prices_2018
# 18  Kensington & Chelsea   1363802.16
# 31           Westminster   1019866.36
# 5                 Camden    842186.93
# 11  Hammersmith & Fulham    725725.49
# 25  Richmond upon Thames    652274.01
# 17             Islington    649532.95
# 30            Wandsworth    596632.27
# 12              Haringey    551552.90
# 10               Hackney    544644.93
# 1                 Barnet    533216.09

# %% [markdown]
# # Visualization of the property price ratio of London borough over two decade

# %%
# Visualization of the property price ratio of London borough over two decade
sns.set_theme(style="white", context="talk")
plt.figure(figsize=(12, 8))

bar_plot = sns.barplot(x='London_borough', y='Price_ratio', data=all_ratios_df.sort_values('Price_ratio'), palette='mako', hue='London_borough', legend=False)

plt.title('Price Ratio for property values in 1998 vs 2018 for Different Boroughs', fontsize=16)
plt.xlabel('London Borough', fontsize=12)
plt.ylabel('Price Ratio (1998 / 2018)', fontsize=12)

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualization of the percentage increase in property price of London borough over two decade

# %%
# Visualization of the percentage increase in property price of London borough over two decade
sns.set_theme(style="white", context="talk")
plt.figure(figsize=(12, 8))

bar_plot = sns.barplot(x='London_borough', y='Price_increase(%)', data=sorted_percentage_increase_df, palette='mako', hue='London_borough', legend=False)

plt.title('Percentage increase in property price of London borough over two decade', fontsize=16)
plt.xlabel('London Borough', fontsize=12)
plt.ylabel('Percentage increase from 1998 to 2018', fontsize=12)

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Average property price of London boroughs 1995-2024

# %%
# Group data by borough and year, calculating the average price per year
avg_price_per_year = properties.groupby(['London_borough', 'Year'])['Average_price'].mean().unstack()

# Plotting all boroughs
plt.figure(figsize=(14, 12))

# Adding grid lines
plt.grid(True, which='both', axis='both', linestyle='--', alpha=0.7)

# Iterate over each borough (row) and plot its data
for borough in avg_price_per_year.index:
    plt.plot(avg_price_per_year.columns, avg_price_per_year.loc[borough], label=borough)

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Average Price (in millions)')
plt.title('Average Property Prices in London Boroughs (1995 - 2024)')

plt.xticks(ticks=range(1995, 2025, 2))  # Display every 2nd year

# Displaying legend outside the plot for clarity
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='London Boroughs')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualizing the property prices in 2018 for the top three London boroughs with the highest price increases

# %%
#  Visualizing the property prices in 2018 for the top three London boroughs with the highest price increases.

sns.set_theme(style="white", context="talk")
plt.figure(figsize=(12, 8))

# Define a custom formatter for y-axis
def millions_formatter(x, pos):
    return f'{x * 1e-6:.1f}M'

# Creating a list of boroughs that reflects most property price increase
highlight = ['Hackney', 'Waltham Forest', 'Southwark']

# Define custom color palette
colors = ['red' if borough in highlight else 'lightskyblue' for borough in price_2018_df.sort_values('Prices_2018')['London_borough']]

bar_plot = sns.barplot(x='London_borough', y='Prices_2018', data=price_2018_df.sort_values('Prices_2018'), palette=colors, hue='London_borough', legend=False)

plt.title('Property Prices of London borough in 2018', fontsize=16)
plt.xlabel('London Borough', fontsize=12)
plt.ylabel('Prices_2018', fontsize=12)

plt.xticks(rotation=90)

# Format the y-axis
ax = plt.gca()  # Get the current axis
ax.yaxis.set_major_formatter(mtick.FuncFormatter(millions_formatter))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# # Introduction

# %% [markdown]
# The purpose of the analysis is to find the London boroughs which have seen the most significant property price increase over two decades. In order to answer this question the ratio of average price of the properties during the year 1998 and 2018 is calculated.

# %% [markdown]
# # Methodology

# %% [markdown]
# The average price during the year 1998 and 2018 were calculated by extracting the year value from the datetime series and subsetting the data for the boroughts on the year 1998 and 2018 to find the mean price over the year. Using this approach a function is created to iterate over all the boroughs to create a dataframe consisting price ratios of the two years 1998 and 2018.

# %% [markdown]
# # Key findings

# %% [markdown]
# The lowest ratio acheived by the boroughs reflects the highest price increase.
#
# Hackney - This borough shows the lowest price ratio resulting the highest property price increase over the two decades.
# Waltham Forest and Southwark are the two other boroughs that has high property price increase.
#
# We can also see that they reside among the mid ranged valued boroughs from the 'Property Prices of London borough in 2018' plot.
# Though 'Hackney' has seen the highest value increase, it still trails behind the the most expensive borough 'Kensington & Chelsea' with a significant price gap of 819K in 2018.
#
# The plot of 'Average Property Prices in London Boroughs (1995 - 2024)' captures the impact of the 2008 financial crisis, as evidenced by a notable dip in property prices across all the London boroughs between the years 2008 and 2009.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The data reveals that  Hackney, Waltham Forest and Southwark have seen the most significant property price increases between 1998 and 2018. These boroughs, once considered less desirable, have now become some of the most sought-after areas in London, reflecting wider trends of urban regeneration and gentrification in the capital.
# Data source
# https://data.london.gov.uk
